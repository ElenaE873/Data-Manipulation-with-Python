# %% [markdown]
# This is a pandas function (not a dataframe method).

# %% [markdown]
# The arguments:
# - df: dataframe we want to transform
# - stubnames: prefix of the columns
# - i argument: name of the index
# - j argument: how we want to name the values of the suffixes
# - sep argument: can be used to separate values of columns by a value
# - suffix argument: with the value "\w+" indicates to pandas that the value end in a word

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### if we want to keep the original index

# %%
#first must reset the index without dropping it
df_with_index.reset_index(drop=False, inplace=True)

#then transform the dataframe
pd.wide_to_long(df_with_index, stubnames=['name1','name2'], i=['column1','column2'], j='name3')

# %% [markdown]
# example:
# ![image.png](attachment:image.png)
